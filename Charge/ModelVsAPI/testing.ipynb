# %%
import requests
from requests_toolbelt.multipart.encoder import MultipartEncoder
import pickle
from data_generator import DataGenerator
import sentence_from_template as sft
from sklearn.metrics import accuracy_score
import numpy as np
from time import sleep
import uuid
from tqdm.notebook import tqdm

# %%
def create_grand_truth(sentence, slots):
    grand_truth = []
    for i, slot in enumerate(slots):
        if slot != "O":
            grand_truth.append((sentence[i], slot))
    return grand_truth

def concat_operator_post(words, slots, word):
    result_word = word
    for i, slot in enumerate(slots):
        if slot == "operator_post":
            result_word = result_word + " " + words[i]
        else:
            break
    return result_word, "operator"

def concat_bnumber_post(words, slots, word):
    result_word = word
    for i, slot in enumerate(slots):
        if slot == "bnumber_post":
            result_word = result_word + " " + words[i]
        else:
            break
    return result_word, "bnumber"

def concat_pnumber_post(words, slots, word):
    result_word = word
    for i, slot in enumerate(slots):
        if slot == "pnumber_post":
            result_word = result_word + " " + words[i]
        else:
            break
    return result_word, "pnumber"

def concat_charge_type_post(words, slots, word):
    result_word = word
    for i, slot in enumerate(slots):
        if slot == "charge_type_post":
            result_word = result_word + " " + words[i]
        else:
            break
    return result_word, "charge_type"

def concat_post(grand_truth):
    words, slots = [ i for i, j in grand_truth ], [ j for i, j in grand_truth ]
    new_words, new_slots = [], []
    for i, slot in enumerate(slots):
        if slot == "operator":
            w, s = concat_operator_post(words[i+1:], slots[i+1:], words[i])
            new_words.append(w)
            new_slots.append(s)
        elif slot == "bnumber":
            w, s = concat_bnumber_post(words[i+1:], slots[i+1:], words[i])
            new_words.append(w)
            new_slots.append(s)
        elif slot == "pnumber":
            w, s = concat_pnumber_post(words[i+1:], slots[i+1:], words[i])
            new_words.append(w)
            new_slots.append(s)
        elif slot == "charge_type":
            w, s = concat_charge_type_post(words[i+1:], slots[i+1:], words[i])
            new_words.append(w)
            new_slots.append(s)
        elif "_post" not in slot:
            new_words.append(words[i])
            new_slots.append(slots[i])
    return new_words, new_slots

# %%
labels_conv = {
    "Operatorname": "operator",
    "AMOUNT": "amount",
    "ORIGINACCOUNT": "bnumber",
    "MOBILENUMBER": "pnumber",
    "chargeType": "charge_type",
}

labels_conv_inv = {
    "operator": "Operatorname",
    "amount": "AMOUNT",
    "bnumber": "ORIGINACCOUNT",
    "pnumber": "MOBILENUMBER",
    "charge_type": "chargeType",
}

# %%
def create_prediction(pred, gt):
    pred_dict = {}
    for p in pred:
        pred_dict[p["name"]] = p["value"]

    if ("unit" in gt.keys()):
        if "توم" in gt["unit"]:
            gt["amount"] = gt["amount"] + "0"
    # print(pred_dict)
    # print(gt)
    prediction_list, grand_truth_list = [], []
    for k in gt.keys():
        if k == "unit":
            continue
        pred_key = labels_conv_inv[k]
        if (pred_key not in pred_dict.keys()) or (pred_dict[pred_key] == None):
            prediction_list.append("----")
        else:
            prediction_list.append(pred_dict[pred_key])
        grand_truth_list.append(gt[k])

    return grand_truth_list, prediction_list

# %%
with open("data.pickle", 'rb') as f:
    data = pickle.load(f)

grand_truths = []
for sentence, slots in zip(data["x"], data["y"]):
    gt = create_grand_truth(sentence, slots)
    new_words, new_slots = concat_post(gt)
    grand_truths.append(dict(list(zip(new_slots, new_words))))


api_url = "https://api.msgata.com/nlu"
accuracies = []
results = []
outputs = []

for i, sentence in tqdm(enumerate(data["x"][:2000])):
    sentence = " ".join(sentence)
    # print(sentence)
    mp_encoder = MultipartEncoder(fields={'text': sentence, "language": "fa", "userId": str(uuid.uuid4())})
    headers = {'Content-Type': mp_encoder.content_type, "devkey": "397124958FA659C9F1A5C7BC96788",
               "token": "12", "Cache-Control": "no-cache",
               "Pragma": "no-cache"}
    res = requests.post(api_url, data=mp_encoder, headers=headers)
    js = res.json()
    result = js['Response']['responses'][0]['entities']
    y, y_pred = create_prediction(result, grand_truths[i])
    results.append((y, y_pred))
    acc = accuracy_score(y, y_pred)
    accuracies.append(acc)
    outputs.append((y, y_pred))
    # print("-----------------")
    # print("")
    # print("")
    # sleep(10)

print(np.mean(accuracies))
print(np.std(accuracies))
print(np.round(np.mean(accuracies), 2))
print(np.round(np.std(accuracies), 2))
# Out:
# 0it [00:00, ?it/s]
# 0.8759
# 0.16441316857235005

# %%
total_slots, missed_slots = 0, 0

for y, y_pred in outputs:
    for i in y:
        total_slots = total_slots + 1
        if i not in y_pred:
            missed_slots = missed_slots + 1

total_slots, total_slots-missed_slots, np.round((total_slots - missed_slots) /  total_slots, 2)
# Out:
# (6460, 5527, 0.86)

# %%
with open("output_txt/output.pickle", "wb") as f:
    pickle.dump(outputs, f)

# %%
for i, sentence in enumerate(data["x"][:2000]):
    sentence = " ".join(sentence)
    y, y_pred = outputs[i]

    with open("./output_txt/_{0}.txt".format(i), "w", encoding='utf-8') as f:
        lines = ["Sentence: \n", sentence+"\n", "Correct: \n",]
        # f.write('Sentence: \n')
        # f.write(sentence)
        # f.write('\n')
        # f.write('Correct: \n')
        for k in y:
            if k in y_pred:
                lines.append(k + ", ")
                # f.write(k)
                # f.write('\n')
        # f.write('Missed: \n')
        lines.append("\nMissed: \n")
        for k in y:
            if k not in y_pred:
                lines.append(k)
                # f.write(k)
                # f.write('\n')
        print(lines)
        f.writelines(lines)
# Out:
# ['Sentence: \n', 'شارژ 6839494 ریالی اینترنت همراه اول واسه خودم میخواستم\n', 'Correct: \n', '6839494, ', 'اینترنت, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'واس کانتکت خودم توسط حساب 4455747125666513 شارژ 4590411 تومان همراه اول کنید\n', 'Correct: \n', '45904110, ', 'همراه اول, ', '\nMissed: \n', '4455747125666513']
# ['Sentence: \n', 'جون مادرت شارژ رایتل اینترنت 8272654 تومن می خوام بوسیله کارت غدچژذ چظخچپطع واس شماره رثو غدنژ رفخذخحض\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '82726540, ', 'رثو غدنژ رفخذخحض, ', '\nMissed: \n', 'غدچژذ چظخچپطع']
# ['Sentence: \n', 'واس مخاطب 91731294043 بوسیله کارت شماره 6663331132434560 شارژ معمولی 8612242 تومانی رایتل بریزین\n', 'Correct: \n', 'معمولی, ', '86122420, ', 'رایتل, ', '\nMissed: \n', '91731294043', '6663331132434560']
# ['Sentence: \n', 'برای خوم شارژ ایرانسل 5137044 تومنی اینترنت می خری لطفا\n', 'Correct: \n', 'ایرانسل, ', '51370440, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 9474626 تومنی سیم میخری\n', 'Correct: \n', '94746260, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 7784941 تومنی توسط کارت 2711556574567644 شارژ معمولی همراه اول سیم بخرید\n', 'Correct: \n', '77849410, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n', '2711556574567644']
# ['Sentence: \n', 'از حساب شماره حژح ذپقچ شارژ 8971204 تومنی\n', 'Correct: \n', '89712040, ', '\nMissed: \n', 'حژح ذپقچ']
# ['Sentence: \n', 'جان مادرت شارژ همراه اول معمولی 412219 ریالی بگیرین برای خط شماره 46887711610 توسط حساب شماره ظجتدقک بجق\n', 'Correct: \n', 'همراه اول, ', 'معمولی, ', '412219, ', 'ظجتدقک بجق, ', '\nMissed: \n', '46887711610']
# ['Sentence: \n', 'واسه خوم شارژ 6061520 تومن رایتل می خوام تو رو خدا\n', 'Correct: \n', '60615200, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل بخرین\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی ایرانسل 8075713 تومنی می کنی واسه شماره موبایل لحبژمیط ملچمض توسط شماره حساب دجبذذ\n', 'Correct: \n', 'معمولی, ', 'ایرانسل, ', '80757130, ', 'لحبژمیط ملچمض, ', '\nMissed: \n', 'دجبذذ']
# ['Sentence: \n', 'واس بنده شارژ 4259233 تومانی شگفت انگیز همراه اول میخرید ممنون میشم\n', 'Correct: \n', '42592330, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 4404648 ریال معمولی همراه اول واسه خودم می خوام\n', 'Correct: \n', '4404648, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'سی شماره تلفن همراه م با کارت 8855867231714659 شارژ 6416141 ریال رایتل بخرین\n', 'Correct: \n', '8855867231714659, ', '6416141, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'خواهشمندم شارژ رایتل شگفت انگیز 4945128 تومنی می خرین به وسیله شماره کارت 6066240633467471 برا تلفن ضتا غزرکبخ سمدشد\n', 'Correct: \n', 'رایتل, ', 'شگفت انگیز, ', '49451280, ', 'ضتا غزرکبخ سمدشد, ', '\nMissed: \n', '6066240633467471']
# ['Sentence: \n', 'سی تلفن 60788743662 با حساب کنبر شارژ اینترنت 1884651 تومنی رایتل میخرید\n', 'Correct: \n', '60788743662, ', 'کنبر, ', 'اینترنت, ', '18846510, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'برام شارژ رایتل 1141301 ریالی اینترنت میگیری خواهش می کنم\n', 'Correct: \n', 'رایتل, ', '1141301, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 1601943 ریالی سی من بکنین\n', 'Correct: \n', '1601943, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 5374802 تومنی بوسیله حساب شماره غتشژمب هزشغرغذ شارژ اینترنت ایرانسل واس خوم بگیرید\n', 'Correct: \n', '53748020, ', 'اینترنت, ', 'ایرانسل, ', '\nMissed: \n', 'غتشژمب هزشغرغذ']
# ['Sentence: \n', 'با کارت شماره 4920941478847898 شارژ 5543377 ریال\n', 'Correct: \n', '5543377, ', '\nMissed: \n', '4920941478847898']
# ['Sentence: \n', 'جان مادرت شارژ ایرانسل اینترنت 6657234 تومانی می خواستم واسه مخاطبین یپپهر با کارت 1774998649193309\n', 'Correct: \n', 'ایرانسل, ', 'اینترنت, ', '66572340, ', '1774998649193309, ', '\nMissed: \n', 'یپپهر']
# ['Sentence: \n', 'واسهم شارژ 8570147 تومان ایرانسل بکنین ممنون می شم\n', 'Correct: \n', '85701470, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ همراه اول میخواستم\n', 'Correct: \n', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ اینترنت رایتل 5667933 ریالی میگیرید سی مخاطب زفاتژ از کارت چاپشمع اطعطط\n', 'Correct: \n', 'اینترنت, ', 'رایتل, ', '5667933, ', 'چاپشمع اطعطط, ', '\nMissed: \n', 'زفاتژ']
# ['Sentence: \n', 'سی مو شارژ 6015106 ریال معمولی ایرانسل میکنی ممنون میشم\n', 'Correct: \n', '6015106, ', 'معمولی, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 5197323 تومن معمولی همراه اول برا بنده بکن\n', 'Correct: \n', '51973230, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'واس کانتکت خودم از حساب شماره 1953842984283566 شارژ 1480698 تومن همراه اول می گیرید\n', 'Correct: \n', '14806980, ', 'همراه اول, ', '\nMissed: \n', '1953842984283566']
# ['Sentence: \n', 'تو رو خدا شارژ رایتل اینترنت 5152402 تومنی میخوام توسط کارت 8234808012391255 برای شماره تلفن 55381857019\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '51524020, ', '55381857019, ', '\nMissed: \n', '8234808012391255']
# ['Sentence: \n', 'برا شماره تلفن همراه 15525679612 بوسیله شماره کارت قذز صتطچیژن خسمنصع شارژ شگفت انگیز 7058710 تومنی همراه اول بگیر\n', 'Correct: \n', '15525679612, ', 'شگفت انگیز, ', '70587100, ', 'همراه اول, ', '\nMissed: \n', 'قذز صتطچیژن خسمنصع']
# ['Sentence: \n', 'برا بنده شارژ رایتل 3790805 تومانی شگفت انگیز می گیرید خواهش می کنم\n', 'Correct: \n', 'رایتل, ', '37908050, ', 'شگفت انگیز, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 4138316 تومن برا مو کنید\n', 'Correct: \n', '41383160, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 4546013 تومان به وسیله شماره حساب تسزس کااشظکه شارژ اینترنت ایرانسل واس مو کنید\n', 'Correct: \n', '45460130, ', 'اینترنت, ', 'ایرانسل, ', '\nMissed: \n', 'تسزس کااشظکه']
# ['Sentence: \n', 'به وسیله شماره حساب 1869819336658581 شارژ 2838149 ریال\n', 'Correct: \n', '2838149, ', '\nMissed: \n', '1869819336658581']
# ['Sentence: \n', 'جان مادرت شارژ رایتل شگفت انگیز 464436 ریال بریزید برای گوشی 74352952654 توسط حساب سجثدسنذ ضضچ\n', 'Correct: \n', 'رایتل, ', 'شگفت انگیز, ', '464436, ', '74352952654, ', '\nMissed: \n', 'سجثدسنذ ضضچ']
# ['Sentence: \n', 'سی خوم شارژ 1448927 تومان رایتل بگیر تو رو خدا\n', 'Correct: \n', '14489270, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ همراه اول می خواستم\n', 'Correct: \n', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ اینترنت ایرانسل 6021613 ریالی میخرین برا کانتکم فتخغ غبج جحظ به وسیله کارت 5989146741761249\n', 'Correct: \n', 'اینترنت, ', 'ایرانسل, ', '6021613, ', '\nMissed: \n', 'فتخغ غبج جحظ', '5989146741761249']
# ['Sentence: \n', 'سی بنده شارژ 6614059 تومنی شگفت انگیز همراه اول میخواستم خواهش میکنم\n', 'Correct: \n', '66140590, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 3914911 ریال معمولی رایتل سیم بکنین\n', 'Correct: \n', '3914911, ', 'معمولی, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه مخاطب من به وسیله شماره کارت بثصچپخم وجه لخمک شارژ 6823632 تومانی رایتل می خرین\n', 'Correct: \n', '68236320, ', 'رایتل, ', '\nMissed: \n', 'بثصچپخم وجه لخمک']
# ['Sentence: \n', 'تو رو خدا شارژ همراه اول شگفت انگیز 4212361 تومان میگیرین توسط کارت ضصخوه سی مخاطب 39180937201\n', 'Correct: \n', 'همراه اول, ', 'شگفت انگیز, ', '42123610, ', '\nMissed: \n', 'ضصخوه', '39180937201']
# ['Sentence: \n', 'واسه موبایل شماره شرهپثبب قممزفی بوسیله حساب 5416827219927149 شارژ معمولی 1951171 ریالی همراه اول می کنین\n', 'Correct: \n', 'شرهپثبب قممزفی, ', 'معمولی, ', '1951171, ', 'همراه اول, ', '\nMissed: \n', '5416827219927149']
# ['Sentence: \n', 'واسه مو شارژ ایرانسل 943628 تومان شگفت انگیز بکنین جون بچت\n', 'Correct: \n', 'ایرانسل, ', '9436280, ', 'شگفت انگیز, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 8344182 ریالی واس خوم بریز\n', 'Correct: \n', '8344182, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 2648761 تومنی به وسیله کارت قیخ شارژ معمولی ایرانسل واس بنده می گیرین\n', 'Correct: \n', '26487610, ', 'معمولی, ', 'ایرانسل, ', '\nMissed: \n', 'قیخ']
# ['Sentence: \n', 'با حساب تششصصحه شارژ 3756983 تومانی\n', 'Correct: \n', 'تششصصحه, ', '37569830, ', '\nMissed: \n']
# ['Sentence: \n', 'لطفا شارژ ایرانسل معمولی 4283596 ریالی بریزید سی شماره تلفن 64148245913 از شماره کارت ظیچخ سخضیه مچلثط\n', 'Correct: \n', 'ایرانسل, ', 'معمولی, ', '4283596, ', '64148245913, ', 'ظیچخ سخضیه مچلثط, ', '\nMissed: \n']
# ['Sentence: \n', 'سی بنده شارژ 3474138 تومن رایتل می کنید جان مادرت\n', 'Correct: \n', '34741380, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل می کنید\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی رایتل 2040484 تومان می کنید واسه شماره تلفن همراه شعضعخبش بوسیله کارت شماره 9975721329154882\n', 'Correct: \n', 'معمولی, ', 'رایتل, ', '20404840, ', 'شعضعخبش, ', '\nMissed: \n', '9975721329154882']
# ['Sentence: \n', 'برا مو شارژ 4596612 ریالی معمولی رایتل می خوام جون بچت\n', 'Correct: \n', '4596612, ', 'معمولی, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 2131577 ریال معمولی ایرانسل واسهم میکنین\n', 'Correct: \n', '2131577, ', 'معمولی, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'سی کانتکتام من توسط شماره حساب کسکشچذچ شارژ 5529445 تومن رایتل بگیرید\n', 'Correct: \n', '55294450, ', 'رایتل, ', '\nMissed: \n', 'کسکشچذچ']
# ['Sentence: \n', 'جان بچت شارژ رایتل شگفت انگیز 9950549 تومان می کنی توسط حساب 2688177531238290 سی شماره غشضظ سذیعظ\n', 'Correct: \n', 'رایتل, ', 'شگفت انگیز, ', '99505490, ', 'غشضظ سذیعظ, ', '\nMissed: \n', '2688177531238290']
# ['Sentence: \n', 'برای کانتکت 71391924557 توسط حساب 5646327757669362 شارژ معمولی 3697526 تومان ایرانسل بگیر\n', 'Correct: \n', 'معمولی, ', '36975260, ', 'ایرانسل, ', '\nMissed: \n', '71391924557', '5646327757669362']
# ['Sentence: \n', 'واسه مو شارژ همراه اول 8119373 تومن معمولی میگیرید خواهشمندم\n', 'Correct: \n', 'همراه اول, ', '81193730, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 8534391 ریال برا من بریزید\n', 'Correct: \n', '8534391, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 3429054 تومنی از شماره کارت پظن ظخزط شارژ شگفت انگیز همراه اول برای خودم می کنین\n', 'Correct: \n', '34290540, ', 'پظن ظخزط, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'بوسیله کارت 4042645245764847 شارژ 7927369 تومنی\n', 'Correct: \n', '79273690, ', '\nMissed: \n', '4042645245764847']
# ['Sentence: \n', 'جان بچت شارژ همراه اول شگفت انگیز 4811848 ریالی میخرید واس شماره ثجر هککغع توسط شماره کارت وهشجعچا ردسث نمذدظک\n', 'Correct: \n', 'همراه اول, ', 'شگفت انگیز, ', '4811848, ', 'ثجر هککغع, ', '\nMissed: \n', 'وهشجعچا ردسث نمذدظک']
# ['Sentence: \n', 'سی من شارژ 4848953 تومنی همراه اول بکنین خواهش می کنم\n', 'Correct: \n', '48489530, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل کنین\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ شگفت انگیز همراه اول 1768759 ریال می خرید واسه خط 13849946758 از حساب شماره وعشذ یکصشعن صذظهشذز\n', 'Correct: \n', 'شگفت انگیز, ', 'همراه اول, ', '1768759, ', '13849946758, ', 'وعشذ یکصشعن صذظهشذز, ', '\nMissed: \n']
# ['Sentence: \n', 'برا بنده شارژ 5004273 تومن شگفت انگیز ایرانسل بریز ممنون میشم\n', 'Correct: \n', '50042730, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 5065390 ریال شگفت انگیز رایتل واسه مو میخواستم\n', 'Correct: \n', '5065390, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'برای گوشی م توسط شماره حساب یحد شارژ 6908864 ریالی رایتل میگیرید\n', 'Correct: \n', '6908864, ', 'رایتل, ', '\nMissed: \n', 'یحد']
# ['Sentence: \n', 'جون بچت شارژ ایرانسل شگفت انگیز 3713588 ریالی بگیر توسط حساب 6744482744183891 برای شماره موبایل رذشچش\n', 'Correct: \n', 'ایرانسل, ', 'شگفت انگیز, ', '3713588, ', 'رذشچش, ', '\nMissed: \n', '6744482744183891']
# ['Sentence: \n', 'واس مخاطبینم 27818831729 توسط شماره کارت جتج عطط دژذنفب شارژ اینترنت 967543 ریال رایتل بکن\n', 'Correct: \n', 'اینترنت, ', '967543, ', 'رایتل, ', '\nMissed: \n', '27818831729', 'جتج عطط دژذنفب']
# ['Sentence: \n', 'برایم شارژ رایتل 1742009 تومنی معمولی بکن خواهشمندم\n', 'Correct: \n', 'رایتل, ', '17420090, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 7294819 ریالی واس خوم میخری\n', 'Correct: \n', '7294819, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 8167322 تومان به وسیله حساب 2638726153482809 شارژ شگفت انگیز همراه اول سیم می گیرید\n', 'Correct: \n', '81673220, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n', '2638726153482809']
# ['Sentence: \n', 'با شماره حساب پکفذضس لدذچ خضنوس شارژ 2655628 تومانی\n', 'Correct: \n', 'پکفذضس لدذچ خضنوس, ', '26556280, ', '\nMissed: \n']
# ['Sentence: \n', 'جون مادرت شارژ همراه اول شگفت انگیز 2991233 تومانی بکن برای شماره موبایل 69562424093 از کارت شماره صطژژ\n', 'Correct: \n', 'همراه اول, ', 'شگفت انگیز, ', '29912330, ', '69562424093, ', 'صطژژ, ', '\nMissed: \n']
# ['Sentence: \n', 'برا بنده شارژ 5641067 تومنی رایتل میکنی جان بچت\n', 'Correct: \n', '56410670, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل کنین\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی همراه اول 3734986 تومن میخرین سی شماره ذمیر لچریطی با حساب 5747412413193184\n', 'Correct: \n', 'معمولی, ', 'همراه اول, ', 'ذمیر لچریطی, ', '5747412413193184, ', '\nMissed: \n', '37349860']
# ['Sentence: \n', 'برا من شارژ 5633754 تومان معمولی همراه اول کنین لطفا\n', 'Correct: \n', '56337540, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 7127801 تومانی شگفت انگیز ایرانسل برای خودم میخرید\n', 'Correct: \n', '71278010, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'سی مخاطبین بنده با کارت شماره 7717715133024966 شارژ 8666067 تومان همراه اول می کنی\n', 'Correct: \n', '86660670, ', 'همراه اول, ', '\nMissed: \n', '7717715133024966']
# ['Sentence: \n', 'جان بچت شارژ رایتل شگفت انگیز 3354515 تومانی بخرید بوسیله شماره کارت تیلذهه دیهسل شیظضعچ واس تلفن شماره تتهضفقو\n', 'Correct: \n', 'رایتل, ', 'شگفت انگیز, ', '33545150, ', 'تتهضفقو, ', '\nMissed: \n', 'تیلذهه دیهسل شیظضعچ']
# ['Sentence: \n', 'برای موبایل 17864719848 با حساب شماره مضنژظط صحاعقهر لطد شارژ معمولی 2770432 تومانی رایتل بگیر\n', 'Correct: \n', '17864719848, ', 'مضنژظط صحاعقهر لطد, ', 'معمولی, ', '27704320, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'برا مو شارژ رایتل 5057590 ریالی معمولی بکنید جان بچت\n', 'Correct: \n', 'رایتل, ', '5057590, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 7771114 ریالی برا من میخواستم\n', 'Correct: \n', '7771114, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 3240035 ریالی به وسیله کارت 8757741721608580 شارژ شگفت انگیز همراه اول برا خودم بخر\n', 'Correct: \n', '3240035, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n', '8757741721608580']
# ['Sentence: \n', 'توسط شماره کارت 9634793789573203 شارژ 37205 تومنی\n', 'Correct: \n', '372050, ', '\nMissed: \n', '9634793789573203']
# ['Sentence: \n', 'جان بچت شارژ رایتل شگفت انگیز 2245766 تومنی می خری سی تلفن همراه شماره هاطپف غقشچدسخ با کارت شماره 2812282159568156\n', 'Correct: \n', 'رایتل, ', 'شگفت انگیز, ', '22457660, ', 'هاطپف غقشچدسخ, ', '\nMissed: \n', '2812282159568156']
# ['Sentence: \n', 'برا خوم شارژ 2014764 ریال رایتل بگیر لطفا\n', 'Correct: \n', '2014764, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ همراه اول کنید\n', 'Correct: \n', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی ایرانسل 3251431 تومن بخرین برای شماره موبایل 57915694540 بوسیله حساب شحطکر فقتزی\n', 'Correct: \n', 'معمولی, ', 'ایرانسل, ', '32514310, ', '57915694540, ', '\nMissed: \n', 'شحطکر فقتزی']
# ['Sentence: \n', 'واسه مو شارژ 5098003 تومن معمولی ایرانسل میخرید ممنون میشم\n', 'Correct: \n', '50980030, ', 'معمولی, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 515536 تومان شگفت انگیز رایتل سی مو میکنید\n', 'Correct: \n', '5155360, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه شماره تلفن همراه خودم به وسیله شماره کارت شحب شارژ 80764 تومنی رایتل می گیرید\n', 'Correct: \n', '807640, ', 'رایتل, ', '\nMissed: \n', 'شحب']
# ['Sentence: \n', 'خواهش میکنم شارژ همراه اول اینترنت 5484937 ریال بریز بوسیله شماره کارت جود ینبج ممکه واس کانتکت ممحصبمع\n', 'Correct: \n', 'همراه اول, ', 'اینترنت, ', '5484937, ', '\nMissed: \n', 'جود ینبج ممکه', 'ممحصبمع']
# ['Sentence: \n', 'واسه شماره موبایل اضاتقجح شغهسپچچ به وسیله کارت 4056596758206522 شارژ شگفت انگیز 5226442 تومن همراه اول بخر\n', 'Correct: \n', 'اضاتقجح شغهسپچچ, ', 'شگفت انگیز, ', '52264420, ', 'همراه اول, ', '\nMissed: \n', '4056596758206522']
# ['Sentence: \n', 'واسه من شارژ رایتل 8618015 ریالی اینترنت میخرین جان بچت\n', 'Correct: \n', 'رایتل, ', '8618015, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 7583035 تومان واس بنده میخرید\n', 'Correct: \n', '75830350, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 2783065 تومانی توسط حساب شماره 5779239031268899 شارژ معمولی همراه اول برا من کن\n', 'Correct: \n', '27830650, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n', '5779239031268899']
# ['Sentence: \n', 'از کارت شماره 2164906733025887 شارژ 4076202 تومن\n', 'Correct: \n', '40762020, ', '\nMissed: \n', '2164906733025887']
# ['Sentence: \n', 'ممنون می شم شارژ ایرانسل شگفت انگیز 8372936 تومنی میخری سی گوشی 30830194487 با حساب شماره سضبپپست طکحح\n', 'Correct: \n', 'ایرانسل, ', 'شگفت انگیز, ', '83729360, ', 'سضبپپست طکحح, ', '\nMissed: \n', '30830194487']
# ['Sentence: \n', 'واس مو شارژ 4980365 تومن رایتل بخرید خواهش می کنم\n', 'Correct: \n', '49803650, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل می خری\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی رایتل 2299530 ریال میخوام برا گوشی 50238436622 با کارت شماره 5938639072138894\n', 'Correct: \n', 'معمولی, ', 'رایتل, ', '2299530, ', '50238436622, ', '\nMissed: \n', '5938639072138894']
# ['Sentence: \n', 'واسه بنده شارژ 4327824 تومانی معمولی ایرانسل میخرین جون مادرت\n', 'Correct: \n', '43278240, ', 'معمولی, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 7981013 تومان اینترنت همراه اول واسهم می گیرید\n', 'Correct: \n', '79810130, ', 'اینترنت, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'برای تلفن خوم به وسیله کارت شماره 5181476980465654 شارژ 1959548 تومان رایتل می خری\n', 'Correct: \n', '19595480, ', 'رایتل, ', '\nMissed: \n', '5181476980465654']
# ['Sentence: \n', 'خواهشمندم شارژ ایرانسل شگفت انگیز 6303789 تومنی بگیرین از حساب شماره 9909692287754553 واسه گوشی لژکطس فاخد اطح\n', 'Correct: \n', 'ایرانسل, ', 'شگفت انگیز, ', '63037890, ', 'لژکطس فاخد اطح, ', '\nMissed: \n', '9909692287754553']
# ['Sentence: \n', 'واس موبایل شماره رقجظلمپ به وسیله حساب شماره هزحمذ ورچو وثژسقا شارژ معمولی 5519085 تومنی رایتل می خرید\n', 'Correct: \n', 'رقجظلمپ, ', 'معمولی, ', '55190850, ', 'رایتل, ', '\nMissed: \n', 'هزحمذ ورچو وثژسقا']
# ['Sentence: \n', 'سی مو شارژ همراه اول 418311 تومن معمولی میخرین خواهش میکنم\n', 'Correct: \n', 'همراه اول, ', '4183110, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 2383852 ریال سی خوم میگیرید\n', 'Correct: \n', '2383852, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 8243299 تومنی بوسیله حساب 7561121014415308 شارژ شگفت انگیز ایرانسل واسه من کنید\n', 'Correct: \n', '82432990, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n', '7561121014415308']
# ['Sentence: \n', 'توسط شماره کارت تشغپ بدصفع شارژ 7957281 ریالی\n', 'Correct: \n', '7957281, ', '\nMissed: \n', 'تشغپ بدصفع']
# ['Sentence: \n', 'جان بچت شارژ ایرانسل شگفت انگیز 6254075 ریال می خرید برای شماره خط یطوژ دمذژثس پپنلمک توسط حساب 5113227094678816\n', 'Correct: \n', 'ایرانسل, ', 'شگفت انگیز, ', '6254075, ', 'یطوژ دمذژثس پپنلمک, ', '\nMissed: \n', '5113227094678816']
# ['Sentence: \n', 'واسهم شارژ 2741772 تومان همراه اول می گیرین خواهشا\n', 'Correct: \n', '27417720, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل بگیرید\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی همراه اول 677343 ریال میکنید واسه شماره 88758343419 از شماره کارت قحجوژ\n', 'Correct: \n', 'معمولی, ', 'همراه اول, ', '677343, ', '88758343419, ', 'قحجوژ, ', '\nMissed: \n']
# ['Sentence: \n', 'سی خودم شارژ 4356441 تومنی معمولی رایتل میکنی خواهشا\n', 'Correct: \n', '43564410, ', 'معمولی, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 8653964 تومن اینترنت رایتل واسه مو میگیرین\n', 'Correct: \n', '86539640, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه شماره تلفن همراه من از شماره کارت نفجسفحص پتف هحلقمف شارژ 3280903 ریالی همراه اول میکنید\n', 'Correct: \n', 'نفجسفحص پتف هحلقمف, ', '3280903, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'ممنون میشم شارژ ایرانسل معمولی 8701865 ریال کنید از حساب شماره خثلشژ واس شماره 21217698100\n', 'Correct: \n', 'ایرانسل, ', 'معمولی, ', '8701865, ', '21217698100, ', '\nMissed: \n', 'خثلشژ']
# ['Sentence: \n', 'برا تلفن 85573129050 به وسیله کارت حسطظسثخ جتضوا شارژ شگفت انگیز 5045070 تومن رایتل میخوام\n', 'Correct: \n', '85573129050, ', 'شگفت انگیز, ', '50450700, ', 'رایتل, ', '\nMissed: \n', 'حسطظسثخ جتضوا']
# ['Sentence: \n', 'واس خوم شارژ رایتل 5998130 تومانی معمولی میگیرید ممنون می شم\n', 'Correct: \n', 'رایتل, ', '59981300, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 9590910 تومانی برا مو بگیرید\n', 'Correct: \n', '95909100, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 1029854 ریالی با حساب 8077916493315137 شارژ شگفت انگیز ایرانسل برای خودم بکنین\n', 'Correct: \n', '1029854, ', '8077916493315137, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'به وسیله کارت شماره 1080390991755665 شارژ 6913975 تومن\n', 'Correct: \n', '69139750, ', '\nMissed: \n', '1080390991755665']
# ['Sentence: \n', 'جون دیت شارژ رایتل شگفت انگیز 6165855 ریال بکن برای کانتکم تصغزلم بوسیله کارت مخحیعصط\n', 'Correct: \n', 'رایتل, ', 'شگفت انگیز, ', '6165855, ', '\nMissed: \n', 'تصغزلم', 'مخحیعصط']
# ['Sentence: \n', 'واس خوم شارژ 3148915 تومانی رایتل میگیری خواهشمندم\n', 'Correct: \n', '31489150, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل میخرید\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ شگفت انگیز همراه اول 3020068 ریالی میخرید واسه موبایل شماره 14606433921 با حساب شماره 5446896840683893\n', 'Correct: \n', 'شگفت انگیز, ', 'همراه اول, ', '3020068, ', '14606433921, ', '\nMissed: \n', '5446896840683893']
# ['Sentence: \n', 'واسه بنده شارژ 1510883 ریال شگفت انگیز رایتل میگیرین جون دیت\n', 'Correct: \n', '1510883, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 8008956 تومن شگفت انگیز رایتل برا خودم بکنید\n', 'Correct: \n', '80089560, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واس تلفن همراه من بوسیله حساب 4447980872934165 شارژ 9014879 تومان رایتل بگیر\n', 'Correct: \n', '90148790, ', 'رایتل, ', '\nMissed: \n', '4447980872934165']
# ['Sentence: \n', 'لطفا شارژ رایتل اینترنت 3767480 تومن کن از شماره حساب ذسذخو برای شماره تلفن همراه 82951217784\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '37674800, ', '82951217784, ', '\nMissed: \n', 'ذسذخو']
# ['Sentence: \n', 'واس تلفن شماره 76771849356 با شماره کارت 1163522443241849 شارژ معمولی 1473247 تومنی رایتل کن\n', 'Correct: \n', '76771849356, ', '1163522443241849, ', 'معمولی, ', '14732470, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه خودم شارژ ایرانسل 2775562 ریال شگفت انگیز می خواستم خواهشمندم\n', 'Correct: \n', 'ایرانسل, ', '2775562, ', 'شگفت انگیز, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 7497834 تومانی برا مو میگیری\n', 'Correct: \n', '74978340, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 3476350 تومانی توسط حساب 4664264298487391 شارژ شگفت انگیز ایرانسل برای مو میخرید\n', 'Correct: \n', '34763500, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n', '4664264298487391']
# ['Sentence: \n', 'توسط شماره کارت 8430988637866932 شارژ 2046277 تومان\n', 'Correct: \n', '20462770, ', '\nMissed: \n', '8430988637866932']
# ['Sentence: \n', 'ممنون میشم شارژ رایتل اینترنت 399850 ریالی کنین واس تلفن شماره یصثچژجف دهثمحغ بوسیله شماره حساب طوکژپصا\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '399850, ', 'یصثچژجف دهثمحغ, ', '\nMissed: \n', 'طوکژپصا']
# ['Sentence: \n', 'واسه من شارژ 8145781 تومن رایتل بگیر خواهش می کنم\n', 'Correct: \n', '81457810, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل کنین\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ اینترنت ایرانسل 5613472 تومنی می خرید واس مخاطب حامم لژم با کارت 8075726743471076\n', 'Correct: \n', 'اینترنت, ', 'ایرانسل, ', '56134720, ', '8075726743471076, ', '\nMissed: \n', 'حامم لژم']
# ['Sentence: \n', 'برا مو شارژ 7348740 تومانی معمولی همراه اول کن جون بچت\n', 'Correct: \n', '73487400, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 3256932 تومن معمولی همراه اول سی مو می خری\n', 'Correct: \n', '32569320, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'برا خط شماره بنده بوسیله کارت شماره صخفص ظیتتیته پلعث شارژ 9125213 ریال رایتل بکن\n', 'Correct: \n', '9125213, ', 'رایتل, ', '\nMissed: \n', 'صخفص ظیتتیته پلعث']
# ['Sentence: \n', 'جون مادرت شارژ رایتل شگفت انگیز 8242129 تومنی میگیری بوسیله شماره حساب 3848572375861800 سی شماره تلفن همراه ثحوغطد اخثذسح\n', 'Correct: \n', 'رایتل, ', 'شگفت انگیز, ', '82421290, ', 'ثحوغطد اخثذسح, ', '\nMissed: \n', '3848572375861800']
# ['Sentence: \n', 'برای شماره تلفن 83764816853 با حساب شماره غکعاعضت شارژ اینترنت 4545890 ریالی رایتل می کنید\n', 'Correct: \n', '83764816853, ', 'غکعاعضت, ', 'اینترنت, ', '4545890, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واس بنده شارژ همراه اول 7522993 ریالی شگفت انگیز می کنید ممنون میشم\n', 'Correct: \n', 'همراه اول, ', '7522993, ', 'شگفت انگیز, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 7193047 تومان برایم میکنی\n', 'Correct: \n', '71930470, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 9934390 تومن توسط شماره کارت وطهچن عظسعمم چهخاتپو شارژ شگفت انگیز ایرانسل سی مو بکن\n', 'Correct: \n', '99343900, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n', 'وطهچن عظسعمم چهخاتپو']
# ['Sentence: \n', 'از حساب ردو دظیقیژ شارژ 3053044 تومنی\n', 'Correct: \n', 'ردو دظیقیژ, ', '30530440, ', '\nMissed: \n']
# ['Sentence: \n', 'جان بچت شارژ ایرانسل اینترنت 5403435 تومن بگیرید سی مخاطبین ذصحطهسک زخزغ به وسیله شماره کارت 5937392189873688\n', 'Correct: \n', 'ایرانسل, ', 'اینترنت, ', '54034350, ', '\nMissed: \n', 'ذصحطهسک زخزغ', '5937392189873688']
# ['Sentence: \n', 'واسه مو شارژ 5378171 تومانی همراه اول می خری جون دیت\n', 'Correct: \n', '53781710, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل کنین\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ اینترنت ایرانسل 226343 ریالی می خوام واسه مخاطب هبعرثه تهچژ از حساب 8040684168373010\n', 'Correct: \n', 'اینترنت, ', 'ایرانسل, ', '226343, ', '8040684168373010, ', '\nMissed: \n', 'هبعرثه تهچژ']
# ['Sentence: \n', 'واس خودم شارژ 3351954 ریال معمولی همراه اول بگیرید ممنون میشم\n', 'Correct: \n', '3351954, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 4047665 ریال معمولی همراه اول واس بنده میکنین\n', 'Correct: \n', '4047665, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'برای شماره تلفن بنده توسط حساب شماره 3098697558826761 شارژ 8419996 تومنی ایرانسل بخرین\n', 'Correct: \n', '84199960, ', 'ایرانسل, ', '\nMissed: \n', '3098697558826761']
# ['Sentence: \n', 'ممنون میشم شارژ همراه اول اینترنت 7267802 تومنی بکن توسط شماره کارت ساقسخن برا مخاطب 16739352007\n', 'Correct: \n', 'همراه اول, ', 'اینترنت, ', '72678020, ', '\nMissed: \n', 'ساقسخن', '16739352007']
# ['Sentence: \n', 'واس کانتکت 84026611638 با کارت شماره 2980833066496822 شارژ شگفت انگیز 2102328 تومن همراه اول بریزین\n', 'Correct: \n', 'شگفت انگیز, ', '21023280, ', 'همراه اول, ', '\nMissed: \n', '84026611638', '2980833066496822']
# ['Sentence: \n', 'سی من شارژ ایرانسل 8435337 ریال اینترنت کنید ممنون میشم\n', 'Correct: \n', 'ایرانسل, ', '8435337, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 2457462 تومان برام کنید\n', 'Correct: \n', '24574620, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 1916934 تومن از حساب وثرحک غیطختض سهت شارژ معمولی رایتل برای من میگیرید\n', 'Correct: \n', '19169340, ', 'وثرحک غیطختض سهت, ', 'معمولی, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'به وسیله کارت شماره ظضتپن پعقعش شارژ 6683646 ریالی\n', 'Correct: \n', '6683646, ', '\nMissed: \n', 'ظضتپن پعقعش']
# ['Sentence: \n', 'جان بچت شارژ همراه اول معمولی 9825872 تومانی میگیری برای شماره تلفن 69844189045 با شماره کارت 7535635857257080\n', 'Correct: \n', 'همراه اول, ', 'معمولی, ', '98258720, ', '69844189045, ', '7535635857257080, ', '\nMissed: \n']
# ['Sentence: \n', 'برا خودم شارژ 3674280 تومان ایرانسل بگیرید جون بچت\n', 'Correct: \n', '36742800, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل بریز\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی رایتل 4923542 تومنی میخوام برای گوشی چضه ذپتهل شسیطغ از شماره حساب 9733384198565894\n', 'Correct: \n', 'معمولی, ', 'رایتل, ', 'چضه ذپتهل شسیطغ, ', '9733384198565894, ', '\nMissed: \n', '49235420']
# ['Sentence: \n', 'سی خودم شارژ 9939207 ریالی شگفت انگیز ایرانسل میخواستم جون دیت\n', 'Correct: \n', '9939207, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 6132127 تومنی معمولی ایرانسل برام می گیرید\n', 'Correct: \n', '61321270, ', 'معمولی, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'واس شماره تلفن همراه خودم از شماره کارت 1575710711875875 شارژ 1860699 تومانی رایتل میگیری\n', 'Correct: \n', '1575710711875875, ', '18606990, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'جون بچت شارژ همراه اول اینترنت 5629447 تومن بخرین توسط حساب شماره 1825219647235776 سی کانتکم ثفصشضز پجغرذظ\n', 'Correct: \n', 'همراه اول, ', 'اینترنت, ', '56294470, ', '\nMissed: \n', '1825219647235776', 'ثفصشضز پجغرذظ']
# ['Sentence: \n', 'سی شماره خط 78647759991 بوسیله حساب شماره 8748641968113163 شارژ شگفت انگیز 5763305 تومانی همراه اول بخرید\n', 'Correct: \n', '78647759991, ', 'شگفت انگیز, ', '57633050, ', 'همراه اول, ', '\nMissed: \n', '8748641968113163']
# ['Sentence: \n', 'سی خوم شارژ رایتل 8401369 تومانی شگفت انگیز بگیر خواهش می کنم\n', 'Correct: \n', 'رایتل, ', '84013690, ', 'شگفت انگیز, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 3830112 تومان سیم می کنی\n', 'Correct: \n', '38301120, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 2085449 تومان توسط شماره حساب ژداب تصثلکه شارژ شگفت انگیز ایرانسل برای بنده میگیرید\n', 'Correct: \n', '20854490, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n', 'ژداب تصثلکه']
# ['Sentence: \n', 'بوسیله کارت شماره 9406784374764423 شارژ 7457896 تومنی\n', 'Correct: \n', '74578960, ', '\nMissed: \n', '9406784374764423']
# ['Sentence: \n', 'جون مادرت شارژ ایرانسل شگفت انگیز 8139252 تومنی بریزید سی موبایل کزفص منیضثژب به وسیله حساب شماره تثنژح\n', 'Correct: \n', 'ایرانسل, ', 'شگفت انگیز, ', '81392520, ', 'کزفص منیضثژب, ', '\nMissed: \n', 'تثنژح']
# ['Sentence: \n', 'برا خوم شارژ 1496935 تومان ایرانسل بریزین خواهشا\n', 'Correct: \n', '14969350, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل بگیر\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی ایرانسل 5140321 ریالی بریزین سی مخاطب قغضزقدا هخذشخل رعفصپ به وسیله کارت شماره 8549194797612445\n', 'Correct: \n', 'معمولی, ', 'ایرانسل, ', '5140321, ', '\nMissed: \n', 'قغضزقدا هخذشخل رعفصپ', '8549194797612445']
# ['Sentence: \n', 'واسه خوم شارژ 9814078 تومن شگفت انگیز همراه اول می گیرین خواهش می کنم\n', 'Correct: \n', '98140780, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 3925425 ریال اینترنت همراه اول سی خوم میخوام\n', 'Correct: \n', '3925425, ', 'اینترنت, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'واس خط شماره م از شماره حساب تپخص ظطنظب صلعپجخث شارژ 318909 تومان رایتل کنید\n', 'Correct: \n', 'تپخص ظطنظب صلعپجخث, ', '3189090, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'خواهش می کنم شارژ ایرانسل معمولی 9637340 تومان بریزید با شماره کارت 4826705436225848 برای مخاطبینم 35275444392\n', 'Correct: \n', 'ایرانسل, ', 'معمولی, ', '96373400, ', '4826705436225848, ', '\nMissed: \n', '35275444392']
# ['Sentence: \n', 'واسه تلفن همراه 58732158333 از کارت 8072323533666862 شارژ معمولی 2117316 تومن همراه اول می گیرید\n', 'Correct: \n', '58732158333, ', '8072323533666862, ', 'معمولی, ', '21173160, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'برا مو شارژ همراه اول 6242384 ریال معمولی بریزید جون مادرت\n', 'Correct: \n', 'همراه اول, ', '6242384, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 2116737 تومانی برای خودم بریز\n', 'Correct: \n', '21167370, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 6930268 ریال توسط حساب 1345913443222828 شارژ معمولی رایتل برام میکنی\n', 'Correct: \n', '6930268, ', 'معمولی, ', 'رایتل, ', '\nMissed: \n', '1345913443222828']
# ['Sentence: \n', 'از کارت ادصزبخ زابط شارژ 5821068 تومان\n', 'Correct: \n', 'ادصزبخ زابط, ', '58210680, ', '\nMissed: \n']
# ['Sentence: \n', 'تو رو خدا شارژ همراه اول معمولی 8738350 ریال بخرین واسه تلفن 81375145194 بوسیله حساب 2010667676106096\n', 'Correct: \n', 'همراه اول, ', 'معمولی, ', '8738350, ', '81375145194, ', '\nMissed: \n', '2010667676106096']
# ['Sentence: \n', 'واسه مو شارژ 6070032 تومنی ایرانسل می کنی لطفا\n', 'Correct: \n', '60700320, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ همراه اول میخری\n', 'Correct: \n', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی رایتل 2080762 ریالی کنید واسه تلفن 12703314453 با حساب شماره عقسجپن زکلزقت وکظشثح\n', 'Correct: \n', 'معمولی, ', 'رایتل, ', '2080762, ', '12703314453, ', 'عقسجپن زکلزقت وکظشثح, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه من شارژ 6620351 ریالی شگفت انگیز ایرانسل میگیری جون دیت\n', 'Correct: \n', '6620351, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 8898682 تومن اینترنت رایتل واس خوم میخوام\n', 'Correct: \n', '88986820, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واس گوشی خودم با حساب شماره شهوقهل شارژ 7054714 تومنی همراه اول می خوام\n', 'Correct: \n', '70547140, ', 'همراه اول, ', '\nMissed: \n', 'شهوقهل']
# ['Sentence: \n', 'ممنون می شم شارژ رایتل اینترنت 9922112 ریال بخرین از شماره حساب 7126814960093983 واس تلفن همراه 99781485776\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '9922112, ', '7126814960093983, ', '99781485776, ', '\nMissed: \n']
# ['Sentence: \n', 'سی تلفن همراه شماره ضوشط خچزت زخر بوسیله حساب شماره 9180993622088429 شارژ اینترنت 6832389 ریالی رایتل میخواستم\n', 'Correct: \n', 'ضوشط خچزت زخر, ', 'اینترنت, ', '6832389, ', 'رایتل, ', '\nMissed: \n', '9180993622088429']
# ['Sentence: \n', 'برا خودم شارژ همراه اول 5613898 تومان اینترنت بریزید جون مادرت\n', 'Correct: \n', 'همراه اول, ', '56138980, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 7969170 ریالی برا من بریز\n', 'Correct: \n', '7969170, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 2000323 تومنی با شماره حساب 1697636374339138 شارژ معمولی ایرانسل واسه خودم میکنی\n', 'Correct: \n', '20003230, ', '1697636374339138, ', 'معمولی, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'بوسیله شماره حساب 8738993593832781 شارژ 8149982 ریال\n', 'Correct: \n', '8149982, ', '\nMissed: \n', '8738993593832781']
# ['Sentence: \n', 'خواهشمندم شارژ رایتل اینترنت 2688323 تومانی بگیر برای خط شماره 55872269894 با شماره حساب 8395242018608057\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '26883230, ', '55872269894, ', '8395242018608057, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه خودم شارژ 4246694 تومنی همراه اول می خرین خواهش میکنم\n', 'Correct: \n', '42466940, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل کن\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ اینترنت ایرانسل 3277343 تومن میگیری سی موبایل لکن دلحشکش ثمکحضفچ توسط حساب حمث\n', 'Correct: \n', 'اینترنت, ', 'ایرانسل, ', '32773430, ', '\nMissed: \n', 'لکن دلحشکش ثمکحضفچ', 'حمث']
# ['Sentence: \n', 'واسه مو شارژ 3328846 تومانی شگفت انگیز ایرانسل میگیرید جون مادرت\n', 'Correct: \n', '33288460, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 4090053 تومان شگفت انگیز رایتل واسه مو میکنین\n', 'Correct: \n', '40900530, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه گوشی م بوسیله شماره حساب دظش تجت زهیزط شارژ 9368665 ریالی ایرانسل میخوام\n', 'Correct: \n', '9368665, ', 'ایرانسل, ', '\nMissed: \n', 'دظش تجت زهیزط']
# ['Sentence: \n', 'جون دیت شارژ رایتل معمولی 5693511 تومن بگیرین توسط شماره کارت رکخ کتیوفل برای تلفن 18072678187\n', 'Correct: \n', 'رایتل, ', 'معمولی, ', '56935110, ', '18072678187, ', '\nMissed: \n', 'رکخ کتیوفل']
# ['Sentence: \n', 'واسه شماره تلفن نتلضذن لصژ به وسیله حساب 3383793538547856 شارژ اینترنت 6956602 تومن همراه اول بریز\n', 'Correct: \n', 'نتلضذن لصژ, ', 'اینترنت, ', '69566020, ', 'همراه اول, ', '\nMissed: \n', '3383793538547856']
# ['Sentence: \n', 'واس بنده شارژ ایرانسل 7730461 تومنی اینترنت بگیرین جان مادرت\n', 'Correct: \n', 'ایرانسل, ', '77304610, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 4593352 تومانی واس خودم میکنی\n', 'Correct: \n', '45933520, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 6042010 تومنی بوسیله شماره حساب ظفح شارژ معمولی رایتل واس بنده می گیرین\n', 'Correct: \n', '60420100, ', 'معمولی, ', 'رایتل, ', '\nMissed: \n', 'ظفح']
# ['Sentence: \n', 'به وسیله حساب شماره 9426564212339511 شارژ 7931450 ریال\n', 'Correct: \n', '7931450, ', '\nMissed: \n', '9426564212339511']
# ['Sentence: \n', 'جان بچت شارژ همراه اول اینترنت 9789197 ریال میکنین سی تلفن همراه ممد غکسیسوز با کارت شماره قسق جهخغ اظصوحپ\n', 'Correct: \n', 'همراه اول, ', 'اینترنت, ', '9789197, ', 'قسق جهخغ اظصوحپ, ', '\nMissed: \n', 'ممد غکسیسوز']
# ['Sentence: \n', 'برای بنده شارژ 6326327 تومان همراه اول بگیر خواهش می کنم\n', 'Correct: \n', '63263270, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل می کنی\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ شگفت انگیز رایتل 4848899 ریالی کنین واس مخاطبین 82924640509 بوسیله شماره کارت اشیروا کبخمسلغ\n', 'Correct: \n', 'شگفت انگیز, ', 'رایتل, ', '4848899, ', '\nMissed: \n', '82924640509', 'اشیروا کبخمسلغ']
# ['Sentence: \n', 'برای من شارژ 5490933 تومانی شگفت انگیز همراه اول می خرین جان مادرت\n', 'Correct: \n', '54909330, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 3012722 تومان اینترنت همراه اول واس خودم می کنین\n', 'Correct: \n', '30127220, ', 'اینترنت, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه خط شماره خودم توسط شماره حساب 2449518993383322 شارژ 8829339 تومانی ایرانسل بکن\n', 'Correct: \n', '88293390, ', 'ایرانسل, ', '\nMissed: \n', '2449518993383322']
# ['Sentence: \n', 'خواهشا شارژ رایتل اینترنت 5204047 تومن میگیرید بوسیله شماره حساب 7706614976244425 برای گوشی 73482775728\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '52040470, ', '73482775728, ', '\nMissed: \n', '7706614976244425']
# ['Sentence: \n', 'سی شماره تلفن همراه 86100605826 از کارت شماره 5776893989261814 شارژ معمولی 826682 ریال رایتل میگیری\n', 'Correct: \n', '86100605826, ', 'معمولی, ', '826682, ', 'رایتل, ', '\nMissed: \n', '5776893989261814']
# ['Sentence: \n', 'واسه من شارژ ایرانسل 2380882 تومان اینترنت میکنی خواهش میکنم\n', 'Correct: \n', 'ایرانسل, ', '23808820, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 4089114 ریالی برا من می گیرید\n', 'Correct: \n', '4089114, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 2951025 تومنی بوسیله شماره حساب 4932199552892602 شارژ شگفت انگیز رایتل واس خودم بریزین\n', 'Correct: \n', '29510250, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n', '4932199552892602']
# ['Sentence: \n', 'به وسیله حساب ژلتغرخه شارژ 1279415 تومان\n', 'Correct: \n', '12794150, ', '\nMissed: \n', 'ژلتغرخه']
# ['Sentence: \n', 'جون دیت شارژ رایتل معمولی 493325 تومنی کنید برای موبایل شماره 17981972426 توسط حساب شماره لنللچز\n', 'Correct: \n', 'رایتل, ', 'معمولی, ', '4933250, ', '17981972426, ', '\nMissed: \n', 'لنللچز']
# ['Sentence: \n', 'واسه خودم شارژ 896694 ریالی همراه اول میخوام جون مادرت\n', 'Correct: \n', '896694, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل بگیر\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ شگفت انگیز همراه اول 6547524 تومانی می گیری واس کانتکم پست با کارت شماره دظوعضکت\n', 'Correct: \n', 'شگفت انگیز, ', 'همراه اول, ', '65475240, ', 'دظوعضکت, ', '\nMissed: \n', 'پست']
# ['Sentence: \n', 'واس من شارژ 2784682 ریال معمولی رایتل میکنین جون مادرت\n', 'Correct: \n', '2784682, ', 'معمولی, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 725110 ریال اینترنت رایتل برا من میخرین\n', 'Correct: \n', '725110, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'برای کانتکتام من از کارت شماره 4547979585357851 شارژ 9513358 تومان ایرانسل بخرین\n', 'Correct: \n', '95133580, ', 'ایرانسل, ', '\nMissed: \n', '4547979585357851']
# ['Sentence: \n', 'لطفا شارژ همراه اول معمولی 356373 ریالی بریزید بوسیله شماره کارت 6699382965417637 برای کانتکت غضثمکمط زظشصض صچنهنقب\n', 'Correct: \n', 'همراه اول, ', 'معمولی, ', '356373, ', '\nMissed: \n', '6699382965417637', 'غضثمکمط زظشصض صچنهنقب']
# ['Sentence: \n', 'سی شماره موبایل ثذظ حرزذپن با حساب سرپتغ شارژ اینترنت 6441706 ریالی ایرانسل میگیرید\n', 'Correct: \n', 'ثذظ حرزذپن, ', 'سرپتغ, ', 'اینترنت, ', '6441706, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه من شارژ ایرانسل 8672534 تومان اینترنت میکنی ممنون میشم\n', 'Correct: \n', 'ایرانسل, ', '86725340, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 5541979 تومان برای بنده می گیرید\n', 'Correct: \n', '55419790, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 7623328 ریال توسط حساب ژچظهشنب وپبپب شارژ اینترنت رایتل برا من بریزید\n', 'Correct: \n', '7623328, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n', 'ژچظهشنب وپبپب']
# ['Sentence: \n', 'از شماره کارت قنن شارژ 4803990 تومنی\n', 'Correct: \n', 'قنن, ', '48039900, ', '\nMissed: \n']
# ['Sentence: \n', 'جون بچت شارژ ایرانسل معمولی 4801329 تومن می خوام برا کانتکت سکق هضتطس چپپح بوسیله شماره حساب 6744710661509656\n', 'Correct: \n', 'ایرانسل, ', 'معمولی, ', '48013290, ', '\nMissed: \n', 'سکق هضتطس چپپح', '6744710661509656']
# ['Sentence: \n', 'واسهم شارژ 1794193 تومان رایتل می خرید جان بچت\n', 'Correct: \n', '17941930, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ همراه اول میخرید\n', 'Correct: \n', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ شگفت انگیز رایتل 7301026 تومن میخرین واس تلفن همراه 90373852685 به وسیله شماره کارت 7958757946093351\n', 'Correct: \n', 'شگفت انگیز, ', 'رایتل, ', '73010260, ', '90373852685, ', '\nMissed: \n', '7958757946093351']
# ['Sentence: \n', 'سی خودم شارژ 5572243 تومان معمولی رایتل می خری خواهشمندم\n', 'Correct: \n', '55722430, ', 'معمولی, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 1619808 ریالی اینترنت ایرانسل واسه خودم میخرید\n', 'Correct: \n', '1619808, ', 'اینترنت, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'سی موبایل خودم توسط حساب 1442831536035341 شارژ 4251990 ریال همراه اول بخرین\n', 'Correct: \n', '4251990, ', 'همراه اول, ', '\nMissed: \n', '1442831536035341']
# ['Sentence: \n', 'خواهش میکنم شارژ همراه اول اینترنت 1594076 تومنی کن به وسیله شماره حساب 2603585165844592 واسه مخاطبینم 16616810278\n', 'Correct: \n', 'همراه اول, ', 'اینترنت, ', '15940760, ', '\nMissed: \n', '2603585165844592', '16616810278']
# ['Sentence: \n', 'برا شماره خط مثصپعط کطدکشوظ صدیپژب به وسیله شماره حساب هخچچدثج حزک شارژ شگفت انگیز 951820 ریال ایرانسل بخرید\n', 'Correct: \n', 'مثصپعط کطدکشوظ صدیپژب, ', 'شگفت انگیز, ', '951820, ', 'ایرانسل, ', '\nMissed: \n', 'هخچچدثج حزک']
# ['Sentence: \n', 'واس مو شارژ رایتل 3786999 تومانی معمولی می خرید خواهشمندم\n', 'Correct: \n', 'رایتل, ', '37869990, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 6953924 ریال واسه خوم می خرین\n', 'Correct: \n', '6953924, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 5229517 تومنی از شماره کارت چچثجذس شارژ شگفت انگیز رایتل واس بنده بکن\n', 'Correct: \n', '52295170, ', 'چچثجذس, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'توسط کارت شماره خری وحق تذف شارژ 8702831 تومنی\n', 'Correct: \n', '87028310, ', '\nMissed: \n', 'خری وحق تذف']
# ['Sentence: \n', 'لطفا شارژ همراه اول شگفت انگیز 3050401 ریال بکنین سی کانتکم ظسطوتذم ورصفاش قحوع با شماره حساب 1424849492987196\n', 'Correct: \n', 'همراه اول, ', 'شگفت انگیز, ', '3050401, ', '1424849492987196, ', '\nMissed: \n', 'ظسطوتذم ورصفاش قحوع']
# ['Sentence: \n', 'واسهم شارژ 1083730 تومن ایرانسل می خواستم جون مادرت\n', 'Correct: \n', '10837300, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل میکنی\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ شگفت انگیز ایرانسل 7812795 تومنی میکنی برا شماره تلفن همقنست اسحدبع به وسیله شماره کارت نصبکذا صغفصاه ظکیظ\n', 'Correct: \n', 'شگفت انگیز, ', 'ایرانسل, ', '78127950, ', 'همقنست اسحدبع, ', '\nMissed: \n', 'نصبکذا صغفصاه ظکیظ']
# ['Sentence: \n', 'سیم شارژ 7921947 ریال شگفت انگیز رایتل میخرید ممنون می شم\n', 'Correct: \n', '7921947, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 1217803 تومانی معمولی همراه اول برا مو بکن\n', 'Correct: \n', '12178030, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'سی تلفن همراه شماره بنده توسط کارت 8239122353658375 شارژ 249605 ریالی همراه اول بکنین\n', 'Correct: \n', '249605, ', 'همراه اول, ', '\nMissed: \n', '8239122353658375']
# ['Sentence: \n', 'خواهش می کنم شارژ ایرانسل معمولی 2378624 تومن میخواستم با حساب شماره جسهظس واس شماره 59531468979\n', 'Correct: \n', 'ایرانسل, ', 'معمولی, ', '23786240, ', '59531468979, ', '\nMissed: \n', 'جسهظس']
# ['Sentence: \n', 'واس تلفن همراه 86183646033 بوسیله کارت شماره صجظسجذ رلش لچتطص شارژ معمولی 6967656 ریال رایتل می گیری\n', 'Correct: \n', 'صجظسجذ رلش لچتطص, ', 'معمولی, ', '6967656, ', 'رایتل, ', '\nMissed: \n', '86183646033']
# ['Sentence: \n', 'برای خوم شارژ رایتل 5536954 ریالی شگفت انگیز بکن خواهش می کنم\n', 'Correct: \n', 'رایتل, ', '5536954, ', 'شگفت انگیز, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 7861654 تومنی سیم بکنید\n', 'Correct: \n', '78616540, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 7625490 تومنی به وسیله حساب شماره 6567900584965753 شارژ شگفت انگیز همراه اول واسه خوم کن\n', 'Correct: \n', '76254900, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n', '6567900584965753']
# ['Sentence: \n', 'با کارت 5485121556923745 شارژ 978860 تومانی\n', 'Correct: \n', '5485121556923745, ', '9788600, ', '\nMissed: \n']
# ['Sentence: \n', 'جون دیت شارژ همراه اول اینترنت 1763957 تومن میخری برا کانتکت ایغچ به وسیله شماره حساب درث\n', 'Correct: \n', 'همراه اول, ', 'اینترنت, ', '17639570, ', '\nMissed: \n', 'ایغچ', 'درث']
# ['Sentence: \n', 'برای خوم شارژ 8169335 تومنی همراه اول میگیرید ممنون می شم\n', 'Correct: \n', '81693350, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل می خرین\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ اینترنت همراه اول 3880804 تومان میخواستم واس شماره خط 79148562024 از حساب 4471964421347555\n', 'Correct: \n', 'اینترنت, ', 'همراه اول, ', '38808040, ', '79148562024, ', '4471964421347555, ', '\nMissed: \n']
# ['Sentence: \n', 'برای بنده شارژ 9392522 ریال اینترنت همراه اول میکنی ممنون میشم\n', 'Correct: \n', '9392522, ', 'اینترنت, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 2314330 تومنی اینترنت رایتل سی خودم بخر\n', 'Correct: \n', '23143300, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه شماره م با شماره کارت 9689106023471221 شارژ 6219472 تومنی رایتل میخرید\n', 'Correct: \n', '9689106023471221, ', '62194720, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'خواهشا شارژ همراه اول اینترنت 7580190 تومنی میخواستم توسط کارت شماره پپصقد واس گوشی 29710397256\n', 'Correct: \n', 'همراه اول, ', 'اینترنت, ', '75801900, ', '\nMissed: \n', 'پپصقد', '29710397256']
# ['Sentence: \n', 'واسه مخاطبینم 58320693768 به وسیله شماره کارت مطی ژلبط غوچخظجپ شارژ اینترنت 8964497 تومن ایرانسل کنین\n', 'Correct: \n', 'اینترنت, ', '89644970, ', 'ایرانسل, ', '\nMissed: \n', '58320693768', 'مطی ژلبط غوچخظجپ']
# ['Sentence: \n', 'واسه خودم شارژ رایتل 5134985 ریال معمولی بریز جون دیت\n', 'Correct: \n', 'رایتل, ', '5134985, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 1670193 ریالی واسه خودم کنین\n', 'Correct: \n', '1670193, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 4009888 تومان توسط شماره حساب بصت جقظغذبض زصظف شارژ اینترنت همراه اول واسم می خرین\n', 'Correct: \n', '40098880, ', 'اینترنت, ', 'همراه اول, ', '\nMissed: \n', 'بصت جقظغذبض زصظف']
# ['Sentence: \n', 'از کارت رحا شارژ 169744 تومنی\n', 'Correct: \n', 'رحا, ', '1697440, ', '\nMissed: \n']
# ['Sentence: \n', 'تو رو خدا شارژ همراه اول شگفت انگیز 299316 ریال بکن سی شماره تلفن قصبز از کارت شماره فظح ظهبم\n', 'Correct: \n', 'همراه اول, ', 'شگفت انگیز, ', '299316, ', 'قصبز, ', 'فظح ظهبم, ', '\nMissed: \n']
# ['Sentence: \n', 'برا خودم شارژ 5302716 تومن همراه اول میکنید جان بچت\n', 'Correct: \n', '53027160, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل میگیرین\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی همراه اول 4982511 تومانی می خوام واس شماره خط 70810635918 توسط کارت شماره 4282435890012920\n', 'Correct: \n', 'معمولی, ', 'همراه اول, ', '49825110, ', '70810635918, ', '\nMissed: \n', '4282435890012920']
# ...
# ['Sentence: \n', 'به وسیله حساب 6486974289137290 شارژ 2977001 ریالی\n', 'Correct: \n', '2977001, ', '\nMissed: \n', '6486974289137290']
# ['Sentence: \n', 'خواهشا شارژ همراه اول اینترنت 8406977 تومانی میخوام سی گوشی 81836764228 بوسیله حساب چحسشزو امدو مجذلپ\n', 'Correct: \n', 'همراه اول, ', 'اینترنت, ', '84069770, ', '81836764228, ', '\nMissed: \n', 'چحسشزو امدو مجذلپ']
# ['Sentence: \n', 'برایم شارژ 4535969 تومان همراه اول می خرید جون دیت\n', 'Correct: \n', '45359690, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل بریزید\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی رایتل 509689 تومانی می کنین برای شماره سزفرظز حسمشج با شماره کارت 7346854279202045\n', 'Correct: \n', 'معمولی, ', 'رایتل, ', '5096890, ', 'سزفرظز حسمشج, ', '7346854279202045, ', '\nMissed: \n']
# ['Sentence: \n', 'واس خودم شارژ 8868237 تومن اینترنت رایتل بگیر جان بچت\n', 'Correct: \n', '88682370, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 6740749 تومنی شگفت انگیز همراه اول سی من میکنی\n', 'Correct: \n', '67407490, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'برای تلفن همراه م به وسیله کارت شماره 6131422948963876 شارژ 3216626 تومن رایتل بکنید\n', 'Correct: \n', '32166260, ', 'رایتل, ', '\nMissed: \n', '6131422948963876']
# ['Sentence: \n', 'جون بچت شارژ همراه اول معمولی 4285553 تومن بریزید توسط شماره حساب ظشزا واس شماره لذشجژک\n', 'Correct: \n', 'همراه اول, ', 'معمولی, ', '42855530, ', 'لذشجژک, ', '\nMissed: \n', 'ظشزا']
# ['Sentence: \n', 'واسه تلفن شماره 44254510543 بوسیله حساب عزاج شارژ معمولی 7159858 ریالی همراه اول بگیرید\n', 'Correct: \n', '44254510543, ', 'معمولی, ', '7159858, ', 'همراه اول, ', '\nMissed: \n', 'عزاج']
# ['Sentence: \n', 'واسه من شارژ ایرانسل 6993577 تومانی شگفت انگیز میگیرید لطفا\n', 'Correct: \n', 'ایرانسل, ', '69935770, ', 'شگفت انگیز, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 422363 تومان برا خودم بگیرید\n', 'Correct: \n', '4223630, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 8197154 ریال از شماره کارت 1298665776348699 شارژ اینترنت همراه اول واس خودم بخرید\n', 'Correct: \n', '8197154, ', '1298665776348699, ', 'اینترنت, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'به وسیله حساب شماره 3906611148355178 شارژ 3305654 تومنی\n', 'Correct: \n', '33056540, ', '\nMissed: \n', '3906611148355178']
# ['Sentence: \n', 'خواهشا شارژ رایتل اینترنت 5603107 تومان بکنین سی مخاطب اورمک لثپعغبش ثفچ با حساب شماره طچثخذ ژطصصژژ میمضمک\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '56031070, ', 'طچثخذ ژطصصژژ میمضمک, ', '\nMissed: \n', 'اورمک لثپعغبش ثفچ']
# ['Sentence: \n', 'برام شارژ 8531037 ریالی رایتل میگیرین تو رو خدا\n', 'Correct: \n', '8531037, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل بگیر\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ شگفت انگیز رایتل 7816301 تومن بخرید سی موبایل شماره 77292333059 به وسیله کارت شماره تتجضک دفقس\n', 'Correct: \n', 'شگفت انگیز, ', 'رایتل, ', '78163010, ', 'تتجضک دفقس, ', '\nMissed: \n', '77292333059']
# ['Sentence: \n', 'واسه خودم شارژ 3843884 ریال معمولی همراه اول میگیری خواهشمندم\n', 'Correct: \n', '3843884, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 4369525 تومنی معمولی رایتل برا بنده بگیر\n', 'Correct: \n', '43695250, ', 'معمولی, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'برای مخاطبینم خودم از کارت شماره 2140921611453279 شارژ 656411 تومانی همراه اول بگیرید\n', 'Correct: \n', '6564110, ', 'همراه اول, ', '\nMissed: \n', '2140921611453279']
# ['Sentence: \n', 'خواهشا شارژ رایتل اینترنت 1383575 ریالی بکنید توسط شماره حساب 7413599811066214 واس خط پژححج جرتفد ژسعصپبز\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '1383575, ', 'پژححج جرتفد ژسعصپبز, ', '\nMissed: \n', '7413599811066214']
# ['Sentence: \n', 'برای کانتکت 20329999897 بوسیله شماره حساب 4307319546481477 شارژ معمولی 2340719 تومن رایتل می خرین\n', 'Correct: \n', 'معمولی, ', '23407190, ', 'رایتل, ', '\nMissed: \n', '20329999897', '4307319546481477']
# ['Sentence: \n', 'واس خودم شارژ رایتل 7717075 تومان اینترنت بخرید خواهش می کنم\n', 'Correct: \n', 'رایتل, ', '77170750, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 3184748 ریالی برام می گیرید\n', 'Correct: \n', '3184748, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 374906 ریال از شماره حساب 4735136597761784 شارژ اینترنت ایرانسل برام می گیری\n', 'Correct: \n', '374906, ', '4735136597761784, ', 'اینترنت, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'با حساب شماره 7156201365434942 شارژ 5375406 تومنی\n', 'Correct: \n', '53754060, ', '\nMissed: \n', '7156201365434942']
# ['Sentence: \n', 'ممنون می شم شارژ همراه اول معمولی 2847474 تومان می خرید برا شماره تلفن همراه 57511507493 بوسیله کارت شماره هیقذ بکفکب لرلدذ\n', 'Correct: \n', 'همراه اول, ', 'معمولی, ', '28474740, ', 'هیقذ بکفکب لرلدذ, ', '\nMissed: \n', '57511507493']
# ['Sentence: \n', 'برا من شارژ 1473672 تومنی ایرانسل می کنی جون مادرت\n', 'Correct: \n', '14736720, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل می کنی\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی همراه اول 3360461 ریال کنید برا شماره 15674528530 به وسیله کارت شماره 6101766294289330\n', 'Correct: \n', 'معمولی, ', 'همراه اول, ', '3360461, ', '15674528530, ', '\nMissed: \n', '6101766294289330']
# ['Sentence: \n', 'واسه بنده شارژ 4277031 تومنی معمولی ایرانسل میکنی خواهشمندم\n', 'Correct: \n', '42770310, ', 'معمولی, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 1952304 تومانی شگفت انگیز رایتل واسه خودم می کنین\n', 'Correct: \n', '19523040, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واس موبایل خودم به وسیله شماره کارت پصمپحع قدماچ ذطژلق شارژ 4082062 تومنی رایتل بریزین\n', 'Correct: \n', '40820620, ', 'رایتل, ', '\nMissed: \n', 'پصمپحع قدماچ ذطژلق']
# ['Sentence: \n', 'ممنون می شم شارژ ایرانسل معمولی 4115128 تومانی بکنید بوسیله حساب 8203472492212638 برا گوشی 17758310716\n', 'Correct: \n', 'ایرانسل, ', 'معمولی, ', '41151280, ', '17758310716, ', '\nMissed: \n', '8203472492212638']
# ['Sentence: \n', 'برا تلفن همراه قپنشبن از حساب 2823677379417627 شارژ اینترنت 3004247 تومن ایرانسل می خواستم\n', 'Correct: \n', '2823677379417627, ', 'اینترنت, ', '30042470, ', 'ایرانسل, ', '\nMissed: \n', 'قپنشبن']
# ['Sentence: \n', 'واس خودم شارژ رایتل 9993122 تومنی شگفت انگیز کنید ممنون میشم\n', 'Correct: \n', 'رایتل, ', '99931220, ', 'شگفت انگیز, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 1004096 تومان واسه مو کنید\n', 'Correct: \n', '10040960, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 1811182 تومنی بوسیله شماره کارت 7002331295382382 شارژ اینترنت رایتل سی مو بکن\n', 'Correct: \n', '18111820, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n', '7002331295382382']
# ['Sentence: \n', 'با کارت شماره 8400335012529447 شارژ 4479443 تومان\n', 'Correct: \n', '44794430, ', '\nMissed: \n', '8400335012529447']
# ['Sentence: \n', 'خواهش می کنم شارژ ایرانسل اینترنت 6957665 تومانی می خرید واسه کانتکتام 15747377136 به وسیله کارت 4031917738631581\n', 'Correct: \n', 'ایرانسل, ', 'اینترنت, ', '69576650, ', '\nMissed: \n', '15747377136', '4031917738631581']
# ['Sentence: \n', 'سیم شارژ 4974019 تومانی ایرانسل می گیرین جون مادرت\n', 'Correct: \n', '49740190, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل میگیری\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی ایرانسل 1932470 ریالی میگیری واسه مخاطب حژثکدم بوسیله حساب شماره 2117383910648885\n', 'Correct: \n', 'معمولی, ', 'ایرانسل, ', '1932470, ', '\nMissed: \n', 'حژثکدم', '2117383910648885']
# ['Sentence: \n', 'واسه مو شارژ 2643456 ریالی معمولی همراه اول میگیرین جان بچت\n', 'Correct: \n', '2643456, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 5769147 تومنی معمولی همراه اول واس خودم بخرید\n', 'Correct: \n', '57691470, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'برا تلفن همراه شماره خوم با کارت شماره جذوچذ تونبث هلثفسفن شارژ 1903971 تومانی همراه اول بگیرید\n', 'Correct: \n', 'جذوچذ تونبث هلثفسفن, ', '19039710, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'ممنون میشم شارژ ایرانسل اینترنت 1798398 تومانی بکن توسط حساب 7850545637083290 واسه کانتکم لصقش\n', 'Correct: \n', 'ایرانسل, ', 'اینترنت, ', '17983980, ', '\nMissed: \n', '7850545637083290', 'لصقش']
# ['Sentence: \n', 'برای کانتکتام ررپ ثشرات هعسصسز از شماره حساب قمنفبسچ شارژ اینترنت 361370 ریالی همراه اول می خرین\n', 'Correct: \n', 'قمنفبسچ, ', 'اینترنت, ', '361370, ', 'همراه اول, ', '\nMissed: \n', 'ررپ ثشرات هعسصسز']
# ['Sentence: \n', 'برام شارژ رایتل 554904 ریال اینترنت میکنید جان بچت\n', 'Correct: \n', 'رایتل, ', '554904, ', 'اینترنت, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 2070429 تومانی واسه مو می خرید\n', 'Correct: \n', '20704290, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 6151898 ریال به وسیله حساب حاشزغ شارژ اینترنت رایتل واسه بنده میکنید\n', 'Correct: \n', '6151898, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n', 'حاشزغ']
# ['Sentence: \n', 'بوسیله کارت 8420566392084272 شارژ 1573949 ریالی\n', 'Correct: \n', '1573949, ', '\nMissed: \n', '8420566392084272']
# ['Sentence: \n', 'جون دیت شارژ همراه اول معمولی 7196418 تومانی بگیر برای شماره 29827971158 از کارت شماره 6292412211465219\n', 'Correct: \n', 'همراه اول, ', 'معمولی, ', '71964180, ', '29827971158, ', '\nMissed: \n', '6292412211465219']
# ['Sentence: \n', 'واسه مو شارژ 8656453 تومنی رایتل می کنی جان بچت\n', 'Correct: \n', '86564530, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل بخرید\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی رایتل 7482655 تومان می خوام واسه موبایل ژثصث چصجقم صهو توسط شماره حساب کششجذ پدر ضدیدی\n', 'Correct: \n', 'معمولی, ', 'رایتل, ', '74826550, ', 'ژثصث چصجقم صهو, ', '\nMissed: \n', 'کششجذ پدر ضدیدی']
# ['Sentence: \n', 'برا مو شارژ 1808289 تومانی اینترنت رایتل کنین جون دیت\n', 'Correct: \n', '18082890, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 5475702 تومان شگفت انگیز رایتل برا خوم می خری\n', 'Correct: \n', '54757020, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه خط شماره بنده با حساب ععق هجور شارژ 1017199 ریال همراه اول میگیری\n', 'Correct: \n', 'ععق هجور, ', '1017199, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'خواهش می کنم شارژ رایتل اینترنت 5793191 ریالی میکنید توسط حساب شماره زیخحث سی مخاطبینم وهه ظقددعض\n', 'Correct: \n', 'رایتل, ', 'اینترنت, ', '5793191, ', '\nMissed: \n', 'زیخحث', 'وهه ظقددعض']
# ['Sentence: \n', 'سی تلفن همراه شماره 17131487146 به وسیله کارت شماره زکشز زعدجهقط شارژ معمولی 6670969 تومن رایتل بخرید\n', 'Correct: \n', 'زکشز زعدجهقط, ', 'معمولی, ', '66709690, ', 'رایتل, ', '\nMissed: \n', '17131487146']
# ['Sentence: \n', 'واسه خودم شارژ همراه اول 9821285 تومنی شگفت انگیز میگیرین خواهشمندم\n', 'Correct: \n', 'همراه اول, ', '98212850, ', 'شگفت انگیز, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 2068502 تومنی برا خوم می کنی\n', 'Correct: \n', '20685020, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 6267038 تومنی از شماره حساب 6080630050256857 شارژ شگفت انگیز ایرانسل سی مو کن\n', 'Correct: \n', '62670380, ', '6080630050256857, ', 'شگفت انگیز, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'با حساب عتغعص شارژ 2526821 ریال\n', 'Correct: \n', 'عتغعص, ', '2526821, ', '\nMissed: \n']
# ['Sentence: \n', 'ممنون می شم شارژ ایرانسل اینترنت 80548 تومانی میگیری سی تلفن شماره عشدفرقج ضتسنحور مطتز به وسیله حساب قکامپدپ جپوجذ\n', 'Correct: \n', 'ایرانسل, ', 'اینترنت, ', '805480, ', 'عشدفرقج ضتسنحور مطتز, ', '\nMissed: \n', 'قکامپدپ جپوجذ']
# ['Sentence: \n', 'برای خودم شارژ 3032559 تومنی ایرانسل میکنی جان مادرت\n', 'Correct: \n', '30325590, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ ایرانسل میخواستم\n', 'Correct: \n', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ معمولی همراه اول 1646308 تومن می گیرید واسه خط حصکفخ مطیژم از حساب شماره 1049446064175200\n', 'Correct: \n', 'معمولی, ', 'همراه اول, ', '16463080, ', 'حصکفخ مطیژم, ', '\nMissed: \n', '1049446064175200']
# ['Sentence: \n', 'سی خودم شارژ 2548708 تومنی شگفت انگیز همراه اول میخواستم تو رو خدا\n', 'Correct: \n', '25487080, ', 'شگفت انگیز, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 50986 ریال معمولی همراه اول برام میخری\n', 'Correct: \n', '50986, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'واسه خط شماره م بوسیله شماره کارت ضظججظوع ضسرنکحل شارژ 199334 ریال ایرانسل میکنید\n', 'Correct: \n', '199334, ', 'ایرانسل, ', '\nMissed: \n', 'ضظججظوع ضسرنکحل']
# ['Sentence: \n', 'لطفا شارژ همراه اول اینترنت 9970466 تومنی بگیرید از حساب قلید وبل یحشخژشط سی شماره موبایل 32770367446\n', 'Correct: \n', 'همراه اول, ', 'اینترنت, ', '99704660, ', '32770367446, ', '\nMissed: \n', 'قلید وبل یحشخژشط']
# ['Sentence: \n', 'واسه مخاطب زضذرایح به وسیله کارت چزطشصلظ طازر شارژ شگفت انگیز 3353644 تومانی همراه اول می خری\n', 'Correct: \n', 'شگفت انگیز, ', '33536440, ', 'همراه اول, ', '\nMissed: \n', 'زضذرایح', 'چزطشصلظ طازر']
# ['Sentence: \n', 'سی بنده شارژ رایتل 1753581 ریال معمولی بریزین ممنون می شم\n', 'Correct: \n', 'رایتل, ', '1753581, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 4146967 تومان برا مو می کنین\n', 'Correct: \n', '41469670, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 173350 تومان به وسیله حساب 3440379723571159 شارژ اینترنت رایتل برا خوم بکنید\n', 'Correct: \n', '1733500, ', 'اینترنت, ', 'رایتل, ', '\nMissed: \n', '3440379723571159']
# ['Sentence: \n', 'توسط حساب 6783342266987337 شارژ 9473731 ریال\n', 'Correct: \n', '9473731, ', '\nMissed: \n', '6783342266987337']
# ['Sentence: \n', 'ممنون می شم شارژ همراه اول شگفت انگیز 6256827 تومان میکنی برا موبایل شماره 63485771483 با حساب شماره 1041985295926800\n', 'Correct: \n', 'همراه اول, ', 'شگفت انگیز, ', '62568270, ', '63485771483, ', '\nMissed: \n', '1041985295926800']
# ['Sentence: \n', 'برایم شارژ 3446314 تومن همراه اول می خری جان مادرت\n', 'Correct: \n', '34463140, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ رایتل می گیرید\n', 'Correct: \n', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ اینترنت رایتل 806744 ریالی میکنی برای موبایل سوطکج با کارت شماره 2672540321342113\n', 'Correct: \n', 'اینترنت, ', 'رایتل, ', '806744, ', 'سوطکج, ', '\nMissed: \n', '2672540321342113']
# ['Sentence: \n', 'واسه خوم شارژ 443180 تومانی شگفت انگیز رایتل می خواستم تو رو خدا\n', 'Correct: \n', '4431800, ', 'شگفت انگیز, ', 'رایتل, ', '\nMissed: \n']
# ['Sentence: \n', 'شارژ 2712180 تومنی معمولی همراه اول سی خودم بگیرید\n', 'Correct: \n', '27121800, ', 'معمولی, ', 'همراه اول, ', '\nMissed: \n']
# ['Sentence: \n', 'برای خط م به وسیله شماره حساب لهفکژ شارژ 22862 ریال رایتل کن\n', 'Correct: \n', '22862, ', 'رایتل, ', '\nMissed: \n', 'لهفکژ']
# ['Sentence: \n', 'جون مادرت شارژ ایرانسل شگفت انگیز 8100605 ریال میکنی از شماره حساب 7613196288591628 واس خط شماره لساپ\n', 'Correct: \n', 'ایرانسل, ', 'شگفت انگیز, ', '8100605, ', '7613196288591628, ', '\nMissed: \n', 'لساپ']
# ['Sentence: \n', 'برای خط شماره 31488651365 توسط حساب 1723705722379742 شارژ معمولی 7836 ریال همراه اول بریزین\n', 'Correct: \n', '31488651365, ', 'معمولی, ', '7836, ', 'همراه اول, ', '\nMissed: \n', '1723705722379742']
# ['Sentence: \n', 'برای خوم شارژ رایتل 2036134 ریال معمولی می گیرین ممنون می شم\n', 'Correct: \n', 'رایتل, ', '2036134, ', 'معمولی, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ 5822142 تومانی برای بنده بگیرید\n', 'Correct: \n', '58221420, ', '\nMissed: \n']
# ['Sentence: \n', 'مبلغ 6892965 تومنی توسط شماره حساب 7257211999608995 شارژ اینترنت ایرانسل واس من می خوام\n', 'Correct: \n', '68929650, ', 'اینترنت, ', 'ایرانسل, ', '\nMissed: \n', '7257211999608995']
# ['Sentence: \n', 'با شماره کارت ژنز لظفنژپ شارژ 2590244 ریالی\n', 'Correct: \n', 'ژنز لظفنژپ, ', '2590244, ', '\nMissed: \n']
# ['Sentence: \n', 'جون دیت شارژ همراه اول شگفت انگیز 661440 تومنی بریز برا موبایل 79993973284 با شماره کارت 6044284054769382\n', 'Correct: \n', 'همراه اول, ', 'شگفت انگیز, ', '6614400, ', '79993973284, ', '6044284054769382, ', '\nMissed: \n']
# ['Sentence: \n', 'واس من شارژ 9357238 ریال ایرانسل می کنی ممنون می شم\n', 'Correct: \n', '9357238, ', 'ایرانسل, ', '\nMissed: \n']
# ['Sentence: \n', 'یه شارژ همراه اول بگیر\n', 'Correct: \n', 'همراه اول, ', '\nMissed: \n']

# %%
type(i)
# Out:
# int

# %%
print(results[-1])
print(data["x"][3])
print(y)
print(y_pred)

# %%
api_url = "https://api.msgata.com/nlu"
mp_encoder = MultipartEncoder(fields={'text': "واس بنده شارژ 15000 تومنی رایتل بخر از حساب 5859831022518434 برای شماره سبا خیاطی",
                                      "language": "fa", "userId": "10"})

# mp_encoder = MultipartEncoder(fields={'text': "خواهش می کنم شارژ خلیج فارس آنلاین اینترنت 8974748 تومن میگیرین به وسیله کارت شماره 3620409980983447 برای مخاطبین 57680905141",
#                                       "language": "fa", "userId": "10"})


# mp_encoder = MultipartEncoder(fields={'text': "واس کانتکت خودم توسط حساب 4455747125666513 شارژ 4590411 تومان همراه اول کنید",
#                                       "language": "fa", "userId": "10"})

mp_encoder = MultipartEncoder(fields={'text': " ".join(data["x"][3]),
                                      "language": "fa", "userId": "10"})

headers = {'Content-Type': mp_encoder.content_type, "devkey": "397124958FA659C9F1A5C7BC96788", "token": "12"}
res = requests.post(api_url, data=mp_encoder, headers=headers)
js = res.json()
js['Response']['responses'][0]['entities']
# Out:
# [{'name': 'chargeType', 'type': 'string', 'value': 'معمولی'},
#  {'name': 'id', 'type': 'number', 'value': '1'},
#  {'name': 'internet', 'type': 'boolean', 'value': 'false'},
#  {'name': 'chargecode', 'type': 'number', 'value': '20'},
#  {'name': 'AMOUNT', 'type': 'number', 'value': '86122420'},
#  {'name': 'Operatorname', 'type': 'string', 'value': 'رایتل'},
#  {'name': 'mobileoperator', 'type': 'string', 'value': 'RIT'},
#  {'name': 'operatorId', 'type': 'number', 'value': '6'},
#  {'name': 'vat', 'type': 'number', 'value': '0'},
#  {'name': 'mobileNumber', 'type': 'number', 'value': None},
#  {'name': 'originAccount', 'type': 'number', 'value': None}]

# %%
js['Response']['responses'][0]['entities']
